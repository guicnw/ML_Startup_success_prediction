# %%
#Muestra Datos

# %%
import pandas as pd

# %%
muestra=pd.read_csv("../data_sample/global_startup_success_dataset.csv",sep=",")
muestra.sample(20)
# Out:
#       Startup Name  Founded Year    Country    Industry Funding Stage  \
# 135    Startup_136          2020         UK    FoodTech      Series C
# 4264  Startup_4265          2007         UK  E-commerce      Series A
# 2137  Startup_2138          2013     Brazil  E-commerce      Series A
# 3392  Startup_3393          2021        USA  Healthcare      Series C
# 4327  Startup_4328          2006  Australia    FoodTech      Series B
# 3862  Startup_3863          2002         UK  Healthcare           IPO
# 3873  Startup_3874          2018    Germany          AI      Series C
# 1202  Startup_1203          2019        USA     FinTech          Seed
# 3970  Startup_3971          2002    Germany    FoodTech          Seed
# 3641  Startup_3642          2022     France  Healthcare           IPO
# 1731  Startup_1732          2009     Brazil    FoodTech      Series B
# 521    Startup_522          2019     France      Energy      Series B
# ...

# %%
muestra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Startup Name              5000 non-null   object
#  1   Founded Year              5000 non-null   int64
#  2   Country                   5000 non-null   object
#  3   Industry                  5000 non-null   object
#  4   Funding Stage             5000 non-null   object
#  5   Total Funding ($M)        5000 non-null   int64
#  6   Number of Employees       5000 non-null   int64
#  7   Annual Revenue ($M)       5000 non-null   int64
#  8   Valuation ($B)            5000 non-null   float64
#  9   Success Score             5000 non-null   int64
#  10  Acquired?                 5000 non-null   object
#  11  IPO?                      5000 non-null   object
#  12  Customer Base (Millions)  5000 non-null   int64
# ...
