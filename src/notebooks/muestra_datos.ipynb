# %%
#Muestra Datos

# %%
import pandas as pd

# %%
muestra=pd.read_csv("../data_sample/global_startup_success_dataset.csv",sep=",")
muestra.sample(20)
# Out:
#       Startup Name  Founded Year    Country    Industry Funding Stage  \
# 4169  Startup_4170          2019     Brazil      Energy      Series B
# 4073  Startup_4074          2016     France        Tech           IPO
# 4838  Startup_4839          2022         UK      Gaming           IPO
# 2315  Startup_2316          2005     Canada   Logistics           IPO
# 2443  Startup_2444          2020      Japan          AI      Series A
# 1965  Startup_1966          2002         UK      Energy          Seed
# 3201  Startup_3202          2001         UK   Logistics           IPO
# 1666  Startup_1667          2015     Brazil   Logistics      Series A
# 2549  Startup_2550          2018     Canada    FoodTech          Seed
# 3530  Startup_3531          2012      India    FoodTech          Seed
# 3447  Startup_3448          2002     Brazil  Healthcare      Series B
# 3182  Startup_3183          2002  Australia   Logistics          Seed
# ...
